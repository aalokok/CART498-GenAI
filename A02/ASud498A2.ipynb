# %%
# Tokenization

from transformers import AutoTokenizer
# To use tokenizers, we import them from the transformers library

# There are many available, use the ID of the model you want to use
# Qwen "Qwen/Qwen2-0.5B"
# GPT-2 "openai-community/gpt2"
# SmolLM "HuggingFaceTB/SomlLM-135M"

prompt = "It was a dark and stormy"
tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
input_ids = tokenizer(prompt).input_ids
input_ids
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [1026, 373, 257, 3223, 290, 6388, 88]

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import torch.nn.functional as F

def get_seventh_most_likely_word(prompt):
    # Load pre-trained model and tokenizer
    model = GPT2LMHeadModel.from_pretrained('gpt2')
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

    # Set the model to evaluation mode
    model.eval()

    # Encode the input text
    inputs = tokenizer.encode(prompt, return_tensors='pt')

    # Generate predictions
    with torch.no_grad():
        outputs = model(inputs)
        predictions = outputs[0]

    # Get the last token's predictions
    next_token_logits = predictions[0, -1, :]

    # Apply softmax to get probabilities
    probabilities = F.softmax(next_token_logits, dim=0)

    # Get top 10 most likely tokens and their probabilities
    top_probs, top_indices = torch.topk(probabilities, k=10)

    # Convert probabilities to percentages
    top_probs = top_probs.mul(100).tolist()
    top_tokens = [tokenizer.decode(idx.item()).strip() for idx in top_indices]

    # Print all top 10 possibilities
    print("Top 10 possible next words:")
    for i, (token, prob) in enumerate(zip(top_tokens, top_probs), 1):
        print(f"{i}. '{token}' - {prob:.2f}% confidence")

    # Get the 7th most likely word (index 6)
    seventh_word = top_tokens[6]
    seventh_prob = top_probs[6]

    return seventh_word, seventh_prob

# Example usage
prompt = "it was a dark and stormy"
word, probability = get_seventh_most_likely_word(prompt)

print(f"\nOriginal prompt: {prompt}")
print(f"7th most likely next word: '{word}' (probability: {probability:.2f}%)")
print(f"Complete sentence: {prompt} {word}")
# Out:
# Top 10 possible next words:
# 1. 'night' - 48.71% confidence
# 2. 'day' - 21.29% confidence
# 3. 'evening' - 4.18% confidence
# 4. 'morning' - 3.57% confidence
# 5. 'afternoon' - 2.42% confidence
# 6. 'place' - 1.41% confidence
# 7. 'time' - 1.37% confidence
# 8. 'summer' - 1.35% confidence
# 9. 'winter' - 1.33% confidence
# 10. 'year' - 0.62% confidence
#
# Original prompt: it was a dark and stormy
# 7th most likely next word: 'time' (probability: 1.37%)
# Complete sentence: it was a dark and stormy time

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import torch.nn.functional as F

def get_seventh_most_likely_word(line):
    # Load pre-trained model and tokenizer
    model = GPT2LMHeadModel.from_pretrained('gpt2')
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model.eval()

    # Encode the input text
    inputs = tokenizer.encode(line, return_tensors='pt')

    # Generate predictions
    with torch.no_grad():
        outputs = model(inputs)
        predictions = outputs[0]

    # Get the last token's predictions
    next_token_logits = predictions[0, -1, :]
    probabilities = F.softmax(next_token_logits, dim=0)

    # Get top 10 most likely tokens and their probabilities
    top_probs, top_indices = torch.topk(probabilities, k=10)
    top_tokens = [tokenizer.decode(idx.item()).strip() for idx in top_indices]

    # Get the 7th most likely word (index 6)
    seventh_word = top_tokens[6]
    return seventh_word

def replace_last_word(poem):
    # Split into lines
    lines = [line.strip() for line in poem.split('\n') if line.strip()]

    modified_lines = []
    title_and_author = lines[:2]  # Keep title and author unchanged
    poem_lines = lines[2:]        # Process only the actual poem lines

    for line in poem_lines:
        # Find the last word
        words = line.split()
        if not words:  # Skip empty lines
            modified_lines.append(line)
            continue

        # Remove the last word and get the context
        context = ' '.join(words[:-1])
        # Get the 7th most likely next word
        new_last_word = get_seventh_most_likely_word(context)
        # Create the new line
        new_line = f"{context} {new_last_word}"
        modified_lines.append(new_line)

    # Combine title, author, and modified lines
    return '\n'.join(title_and_author + modified_lines)

# Original poem
original_poem = """The Snow Man
by Wallace Stevens (1879-1955)
One must have a mind of winter
To regard the frost and the boughs
Of the pine-trees crusted with snow;
And have been cold a long time
To behold the junipers shagged with ice,
The spruces rough in the distant glitter
Of the January sun; and not to think
Of any misery in the sound of the wind,
In the sound of a few leaves,
Which is the sound of the land
Full of the same wind
That is blowing in the same bare place
For the listener, who listens in the snow,
And, nothing himself, beholds
Nothing that is not there and the nothing that is."""

# Print original and modified versions side by side
print("Original Poem:")
print("-" * 50)
print(original_poem)
print("\nModified Poem (with 7th most likely words):")
print("-" * 50)
modified_poem = replace_last_word(original_poem)
print(modified_poem)
# Out:
# Original Poem:
# --------------------------------------------------
# The Snow Man
# by Wallace Stevens (1879-1955)
# One must have a mind of winter
# To regard the frost and the boughs
# Of the pine-trees crusted with snow;
# And have been cold a long time
# To behold the junipers shagged with ice,
# The spruces rough in the distant glitter
# Of the January sun; and not to think
# Of any misery in the sound of the wind,
# In the sound of a few leaves,
# Which is the sound of the land
# Full of the same wind
# That is blowing in the same bare place
# For the listener, who listens in the snow,
# And, nothing himself, beholds
# Nothing that is not there and the nothing that is.
#
# Modified Poem (with 7th most likely words):
# --------------------------------------------------
# The Snow Man
# by Wallace Stevens (1879-1955)
# One must have a mind of her
# To regard the frost and the death
# Of the pine-trees crusted with oil
# And have been cold a long way
# To behold the junipers shagged with white
# The spruces rough in the distant horizon
# Of the January sun; and not to have
# Of any misery in the sound of the sound
# In the sound of a few shots
# Which is the sound of the voice
# Full of the same day
# That is blowing in the same bare air
# For the listener, who listens in the morning
# And, nothing himself, I
# Nothing that is not there and the nothing that isn

# %% [markdown]
# This Code snippet will give top 10 word probabilities for every line

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import torch.nn.functional as F

def get_top_ten_words(line):
    # Load pre-trained model and tokenizer
    model = GPT2LMHeadModel.from_pretrained('gpt2')
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model.eval()

    # Encode the input text
    inputs = tokenizer.encode(line, return_tensors='pt')

    # Generate predictions
    with torch.no_grad():
        outputs = model(inputs)
        predictions = outputs[0]

    # Get the last token's predictions
    next_token_logits = predictions[0, -1, :]
    probabilities = F.softmax(next_token_logits, dim=0)

    # Get top 10 most likely tokens and their probabilities
    top_probs, top_indices = torch.topk(probabilities, k=10)
    top_probs = top_probs.mul(100).tolist()  # Convert to percentages
    top_tokens = [tokenizer.decode(idx.item()).strip() for idx in top_indices]

    return list(zip(top_tokens, top_probs))

def process_poem(poem):
    # Split into lines
    lines = [line.strip() for line in poem.split('\n') if line.strip()]

    title_and_author = lines[:2]  # Keep title and author unchanged
    poem_lines = lines[2:]        # Process only the actual poem lines

    modified_lines = []
    print("\nAnalyzing each line's possibilities:")
    print("=" * 80)

    for i, line in enumerate(poem_lines, 1):
        words = line.split()
        if not words:  # Skip empty lines
            modified_lines.append(line)
            continue

        # Get context (everything except last word)
        context = ' '.join(words[:-1])
        original_last_word = words[-1]

        # Get and display top 10 possibilities
        print(f"\nLine {i}: \"{line}\"")
        print("-" * 40)
        print("Top 10 possibilities for the last word:")
        top_ten = get_top_ten_words(context)
        for j, (word, prob) in enumerate(top_ten, 1):
            print(f"{j}. '{word}' - {prob:.2f}% confidence")
            if j == 7:  # Highlight the chosen word
                print(f"   ^^^ This word will be used ^^^")

        # Create new line with 7th most likely word
        new_last_word = top_ten[6][0]
        new_line = f"{context} {new_last_word}"
        modified_lines.append(new_line)

    # Combine everything
    return '\n'.join(title_and_author + modified_lines)

# Original poem
original_poem = """The Snow Man
by Wallace Stevens (1879-1955)
One must have a mind of winter
To regard the frost and the boughs
Of the pine-trees crusted with snow;
And have been cold a long time
To behold the junipers shagged with ice,
The spruces rough in the distant glitter
Of the January sun; and not to think
Of any misery in the sound of the wind,
In the sound of a few leaves,
Which is the sound of the land
Full of the same wind
That is blowing in the same bare place
For the listener, who listens in the snow,
And, nothing himself, beholds
Nothing that is not there and the nothing that is."""

print("Original Poem:")
print("-" * 50)
print(original_poem)

modified_poem = process_poem(original_poem)

print("\n\nFinal Modified Poem:")
print("-" * 50)
print(modified_poem)
# Out:
# Original Poem:
# --------------------------------------------------
# The Snow Man
# by Wallace Stevens (1879-1955)
# One must have a mind of winter
# To regard the frost and the boughs
# Of the pine-trees crusted with snow;
# And have been cold a long time
# To behold the junipers shagged with ice,
# The spruces rough in the distant glitter
# Of the January sun; and not to think
# Of any misery in the sound of the wind,
# In the sound of a few leaves,
# Which is the sound of the land
# Full of the same wind
# That is blowing in the same bare place
# For the listener, who listens in the snow,
# And, nothing himself, beholds
# Nothing that is not there and the nothing that is.
#
# Analyzing each line's possibilities:
# ================================================================================
#
# Line 1: "One must have a mind of winter"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'their' - 32.77% confidence
# 2. 'its' - 13.43% confidence
# 3. 'his' - 13.04% confidence
# 4. 'your' - 2.48% confidence
# 5. 'a' - 2.02% confidence
# 6. 'our' - 1.69% confidence
# 7. 'her' - 1.62% confidence
#    ^^^ This word will be used ^^^
# 8. 'this' - 1.23% confidence
# 9. 'my' - 1.16% confidence
# 10. 'one' - 1.09% confidence
#
# Line 2: "To regard the frost and the boughs"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'cold' - 1.96% confidence
# 2. 'snow' - 1.51% confidence
# 3. 'frost' - 1.18% confidence
# 4. 'ice' - 1.14% confidence
# 5. 'fire' - 0.91% confidence
# 6. 'wind' - 0.75% confidence
# 7. 'death' - 0.64% confidence
#    ^^^ This word will be used ^^^
# 8. 'fall' - 0.64% confidence
# 9. 'heat' - 0.63% confidence
# 10. 'storm' - 0.61% confidence
#
# Line 3: "Of the pine-trees crusted with snow;"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'the' - 5.27% confidence
# 2. 'a' - 2.35% confidence
# 3. 'pine' - 1.83% confidence
# 4. 'salt' - 0.98% confidence
# 5. 'blood' - 0.98% confidence
# 6. 'red' - 0.92% confidence
# 7. 'oil' - 0.81% confidence
#    ^^^ This word will be used ^^^
# 8. 'gold' - 0.77% confidence
# 9. 'black' - 0.72% confidence
# 10. 'white' - 0.68% confidence
#
# Line 4: "And have been cold a long time"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'time' - 92.33% confidence
# 2. 'while' - 4.42% confidence
# 3. ',' - 0.73% confidence
# 4. 'enough' - 0.24% confidence
# 5. 'long' - 0.24% confidence
# 6. 'day' - 0.20% confidence
# 7. 'way' - 0.15% confidence
#    ^^^ This word will be used ^^^
# 8. 'few' - 0.07% confidence
# 9. 'time' - 0.06% confidence
# 10. 'and' - 0.06% confidence
#
# Line 5: "To behold the junipers shagged with ice,"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'the' - 10.30% confidence
# 2. 'their' - 9.06% confidence
# 3. 'a' - 8.25% confidence
# 4. 'blood' - 1.12% confidence
# 5. 'an' - 1.06% confidence
# 6. 'black' - 0.97% confidence
# 7. 'white' - 0.84% confidence
#    ^^^ This word will be used ^^^
# 8. 'red' - 0.83% confidence
# 9. 'his' - 0.74% confidence
# 10. 'tw' - 0.51% confidence
#
# Line 6: "The spruces rough in the distant glitter"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'hills' - 6.36% confidence
# 2. 'past' - 5.83% confidence
# 3. 'mountains' - 2.97% confidence
# 4. ',' - 2.79% confidence
# 5. 'sky' - 2.44% confidence
# 6. 'future' - 1.98% confidence
# 7. 'horizon' - 1.97% confidence
#    ^^^ This word will be used ^^^
# 8. 'night' - 1.49% confidence
# 9. 'woods' - 1.22% confidence
# 10. 'distance' - 1.00% confidence
#
# Line 7: "Of the January sun; and not to think"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'be' - 16.31% confidence
# 2. 'mention' - 8.23% confidence
# 3. 'the' - 4.81% confidence
# 4. 'say' - 4.69% confidence
# 5. 'forget' - 2.43% confidence
# 6. 'speak' - 2.17% confidence
# 7. 'have' - 1.29% confidence
#    ^^^ This word will be used ^^^
# 8. 'think' - 1.26% confidence
# 9. 'look' - 0.97% confidence
# 10. 'my' - 0.91% confidence
#
# Line 8: "Of any misery in the sound of the wind,"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'trumpet' - 2.44% confidence
# 2. 'voice' - 2.19% confidence
# 3. 'bell' - 1.67% confidence
# 4. 'world' - 1.65% confidence
# 5. 'bells' - 1.07% confidence
# 6. 'wind' - 1.04% confidence
# 7. 'sound' - 1.00% confidence
#    ^^^ This word will be used ^^^
# 8. 'music' - 0.89% confidence
# 9. 'drum' - 0.86% confidence
# 10. 'earth' - 0.84% confidence
#
# Line 9: "In the sound of a few leaves,"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'words' - 3.48% confidence
# 2. 'voices' - 2.31% confidence
# 3. 'of' - 2.29% confidence
# 4. 'gunshots' - 2.09% confidence
# 5. 'feet' - 1.36% confidence
# 6. 'clicks' - 1.34% confidence
# 7. 'shots' - 1.25% confidence
#    ^^^ This word will be used ^^^
# 8. 'more' - 1.17% confidence
# 9. 'minutes' - 1.05% confidence
# 10. 'loud' - 0.98% confidence
#
# Line 10: "Which is the sound of the land"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'wind' - 1.17% confidence
# 2. 'car' - 1.07% confidence
# 3. 'door' - 0.94% confidence
# 4. 'engine' - 0.85% confidence
# 5. 'water' - 0.82% confidence
# 6. 'sound' - 0.75% confidence
# 7. 'voice' - 0.73% confidence
#    ^^^ This word will be used ^^^
# 8. 'bell' - 0.67% confidence
# 9. 'drum' - 0.55% confidence
# 10. 'music' - 0.55% confidence
#
# Line 11: "Full of the same wind"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. ',' - 5.23% confidence
# 2. '.' - 5.07% confidence
# 3. 'kind' - 1.79% confidence
# 4. 'name' - 1.55% confidence
# 5. 'thing' - 1.48% confidence
# 6. 'type' - 1.45% confidence
# 7. 'day' - 1.19% confidence
#    ^^^ This word will be used ^^^
# 8. 'material' - 0.96% confidence
# 9. 'story' - 0.94% confidence
# 10. 'time' - 0.76% confidence
#
# Line 12: "That is blowing in the same bare place"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. '-' - 4.74% confidence
# 2. 'foot' - 3.32% confidence
# 3. 'feet' - 2.85% confidence
# 4. 'chest' - 2.81% confidence
# 5. 'hands' - 2.73% confidence
# 6. ',' - 2.19% confidence
# 7. 'air' - 2.17% confidence
#    ^^^ This word will be used ^^^
# 8. 'shoulders' - 1.90% confidence
# 9. 'footed' - 1.81% confidence
# 10. 'bones' - 1.42% confidence
#
# Line 13: "For the listener, who listens in the snow,"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'background' - 16.32% confidence
# 2. 'same' - 7.84% confidence
# 3. 'middle' - 2.07% confidence
# 4. 'first' - 1.74% confidence
# 5. 'browser' - 1.58% confidence
# 6. '"' - 1.17% confidence
# 7. 'morning' - 0.87% confidence
#    ^^^ This word will be used ^^^
# 8. 'following' - 0.74% confidence
# 9. 'main' - 0.73% confidence
# 10. 'studio' - 0.70% confidence
#
# Line 14: "And, nothing himself, beholds"
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'but' - 14.43% confidence
# 2. 'nothing' - 6.89% confidence
# 3. 'except' - 5.01% confidence
# 4. 'no' - 3.25% confidence
# 5. 'and' - 3.16% confidence
# 6. 'he' - 2.70% confidence
# 7. 'I' - 2.31% confidence
#    ^^^ This word will be used ^^^
# 8. 'not' - 2.24% confidence
# 9. 'or' - 2.16% confidence
# 10. 'though' - 2.09% confidence
#
# Line 15: "Nothing that is not there and the nothing that is."
# ----------------------------------------
# Top 10 possibilities for the last word:
# 1. 'is' - 64.99% confidence
# 2. 'has' - 2.63% confidence
# 3. 'does' - 1.97% confidence
# 4. 'was' - 1.71% confidence
# 5. 'I' - 1.44% confidence
# 6. 'we' - 1.43% confidence
# 7. 'isn' - 1.36% confidence
#    ^^^ This word will be used ^^^
# 8. ''s' - 1.30% confidence
# 9. 'you' - 1.07% confidence
# 10. 'comes' - 1.05% confidence
#
#
# Final Modified Poem:
# --------------------------------------------------
# The Snow Man
# by Wallace Stevens (1879-1955)
# One must have a mind of her
# To regard the frost and the death
# Of the pine-trees crusted with oil
# And have been cold a long way
# To behold the junipers shagged with white
# The spruces rough in the distant horizon
# Of the January sun; and not to have
# Of any misery in the sound of the sound
# In the sound of a few shots
# Which is the sound of the voice
# Full of the same day
# That is blowing in the same bare air
# For the listener, who listens in the morning
# And, nothing himself, I
# Nothing that is not there and the nothing that isn

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
import torch.nn.functional as F

def get_top_words(line, k=20):  # Get 20 to ensure we have enough valid options
    # Load pre-trained model and tokenizer
    model = GPT2LMHeadModel.from_pretrained('gpt2')
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    model.eval()

    # Encode the input text
    inputs = tokenizer.encode(line, return_tensors='pt')

    # Generate predictions
    with torch.no_grad():
        outputs = model(inputs)
        predictions = outputs[0]

    # Get the last token's predictions
    next_token_logits = predictions[0, -1, :]
    probabilities = F.softmax(next_token_logits, dim=0)

    # Get top k most likely tokens and their probabilities
    top_probs, top_indices = torch.topk(probabilities, k=k)
    top_probs = top_probs.mul(100).tolist()  # Convert to percentages
    top_tokens = [tokenizer.decode(idx.item()).strip() for idx in top_indices]

    return list(zip(top_tokens, top_probs))

def process_poem(poem):
    # Split into lines
    lines = [line.strip() for line in poem.split('\n') if line.strip()]

    title_and_author = lines[:2]  # Keep title and author unchanged
    poem_lines = lines[2:]        # Process only the actual poem lines

    modified_lines = []
    print("\nAnalyzing each line's possibilities:")
    print("=" * 80)

    for i, line in enumerate(poem_lines, 1):
        words = line.split()
        if not words:  # Skip empty lines
            modified_lines.append(line)
            continue

        # Get context (everything except last word)
        context = ' '.join(words[:-1])
        original_last_word = words[-1]

        # Get and display top possibilities
        print(f"\nLine {i}: \"{line}\"")
        print("-" * 40)
        print("Top 20 possibilities for the last word:")
        top_words = get_top_words(context)
        for j, (word, prob) in enumerate(top_words, 1):
            print(f"{j}. '{word}' - {prob:.2f}% confidence")
            if j == 15:  # Highlight the chosen word
                print(f"   ^^^ This word will be used ^^^")

        # Create new line with 15th most likely word
        new_last_word = top_words[14][0]  # Index 14 for 15th word (0-based indexing)
        new_line = f"{context} {new_last_word}"
        modified_lines.append(new_line)

    # Combine everything
    return '\n'.join(title_and_author + modified_lines)

# Original poem
original_poem = """The Snow Man
by Wallace Stevens (1879-1955)
One must have a mind of winter
To regard the frost and the boughs
Of the pine-trees crusted with snow;
And have been cold a long time
To behold the junipers shagged with ice,
The spruces rough in the distant glitter
Of the January sun; and not to think
Of any misery in the sound of the wind,
In the sound of a few leaves,
Which is the sound of the land
Full of the same wind
That is blowing in the same bare place
For the listener, who listens in the snow,
And, nothing himself, beholds
Nothing that is not there and the nothing that is."""

print("Original Poem:")
print("-" * 50)
print(original_poem)

modified_poem = process_poem(original_poem)

print("\n\nFinal Modified Poem:")
print("-" * 50)
print(modified_poem)
# Out:
# Original Poem:
# --------------------------------------------------
# The Snow Man
# by Wallace Stevens (1879-1955)
# One must have a mind of winter
# To regard the frost and the boughs
# Of the pine-trees crusted with snow;
# And have been cold a long time
# To behold the junipers shagged with ice,
# The spruces rough in the distant glitter
# Of the January sun; and not to think
# Of any misery in the sound of the wind,
# In the sound of a few leaves,
# Which is the sound of the land
# Full of the same wind
# That is blowing in the same bare place
# For the listener, who listens in the snow,
# And, nothing himself, beholds
# Nothing that is not there and the nothing that is.
#
# Analyzing each line's possibilities:
# ================================================================================
#
# Line 1: "One must have a mind of winter"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'their' - 32.77% confidence
# 2. 'its' - 13.43% confidence
# 3. 'his' - 13.04% confidence
# 4. 'your' - 2.48% confidence
# 5. 'a' - 2.02% confidence
# 6. 'our' - 1.69% confidence
# 7. 'her' - 1.62% confidence
# 8. 'this' - 1.23% confidence
# 9. 'my' - 1.16% confidence
# 10. 'one' - 1.09% confidence
# 11. 'the' - 0.83% confidence
# 12. 'balance' - 0.58% confidence
# 13. '"' - 0.52% confidence
# 14. 'what' - 0.45% confidence
# 15. 'it' - 0.41% confidence
#    ^^^ This word will be used ^^^
# 16. 'some' - 0.41% confidence
# 17. ''' - 0.35% confidence
# 18. 'good' - 0.34% confidence
# 19. 'how' - 0.31% confidence
# 20. 'steel' - 0.30% confidence
#
# Line 2: "To regard the frost and the boughs"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'cold' - 1.96% confidence
# 2. 'snow' - 1.51% confidence
# 3. 'frost' - 1.18% confidence
# 4. 'ice' - 1.14% confidence
# 5. 'fire' - 0.91% confidence
# 6. 'wind' - 0.75% confidence
# 7. 'death' - 0.64% confidence
# 8. 'fall' - 0.64% confidence
# 9. 'heat' - 0.63% confidence
# 10. 'storm' - 0.61% confidence
# 11. 'other' - 0.55% confidence
# 12. 'rain' - 0.53% confidence
# 13. 'sun' - 0.47% confidence
# 14. 'water' - 0.35% confidence
# 15. 'lack' - 0.34% confidence
#    ^^^ This word will be used ^^^
# 16. 'freezing' - 0.34% confidence
# 17. 'sudden' - 0.29% confidence
# 18. 'subsequent' - 0.29% confidence
# 19. 'destruction' - 0.29% confidence
# 20. 'darkness' - 0.28% confidence
#
# Line 3: "Of the pine-trees crusted with snow;"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'the' - 5.27% confidence
# 2. 'a' - 2.35% confidence
# 3. 'pine' - 1.83% confidence
# 4. 'salt' - 0.98% confidence
# 5. 'blood' - 0.98% confidence
# 6. 'red' - 0.92% confidence
# 7. 'oil' - 0.81% confidence
# 8. 'gold' - 0.77% confidence
# 9. 'black' - 0.72% confidence
# 10. 'white' - 0.68% confidence
# 11. 'moss' - 0.63% confidence
# 12. 'ash' - 0.57% confidence
# 13. 'their' - 0.57% confidence
# 14. 'leaves' - 0.56% confidence
# 15. 'dust' - 0.51% confidence
#    ^^^ This word will be used ^^^
# 16. 'dirt' - 0.47% confidence
# 17. 'dried' - 0.44% confidence
# 18. 'fire' - 0.43% confidence
# 19. 'snow' - 0.42% confidence
# 20. 'his' - 0.37% confidence
#
# Line 4: "And have been cold a long time"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'time' - 92.33% confidence
# 2. 'while' - 4.42% confidence
# 3. ',' - 0.73% confidence
# 4. 'enough' - 0.24% confidence
# 5. 'long' - 0.24% confidence
# 6. 'day' - 0.20% confidence
# 7. 'way' - 0.15% confidence
# 8. 'few' - 0.07% confidence
# 9. 'time' - 0.06% confidence
# 10. 'and' - 0.06% confidence
# 11. 'moment' - 0.05% confidence
# 12. 'year' - 0.05% confidence
# 13. '-' - 0.05% confidence
# 14. 'week' - 0.04% confidence
# 15. 'period' - 0.04% confidence
#    ^^^ This word will be used ^^^
# 16. 'night' - 0.04% confidence
# 17. 'bit' - 0.04% confidence
# 18. 'stretch' - 0.03% confidence
# 19. 'number' - 0.03% confidence
# 20. 'hard' - 0.02% confidence
#
# Line 5: "To behold the junipers shagged with ice,"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'the' - 10.30% confidence
# 2. 'their' - 9.06% confidence
# 3. 'a' - 8.25% confidence
# 4. 'blood' - 1.12% confidence
# 5. 'an' - 1.06% confidence
# 6. 'black' - 0.97% confidence
# 7. 'white' - 0.84% confidence
# 8. 'red' - 0.83% confidence
# 9. 'his' - 0.74% confidence
# 10. 'tw' - 0.51% confidence
# 11. 'its' - 0.49% confidence
# 12. 'iron' - 0.48% confidence
# 13. 'arrows' - 0.41% confidence
# 14. 'feathers' - 0.41% confidence
# 15. 'silver' - 0.40% confidence
#    ^^^ This word will be used ^^^
# 16. 'her' - 0.37% confidence
# 17. 'sharp' - 0.34% confidence
# 18. 'some' - 0.34% confidence
# 19. 'yellow' - 0.33% confidence
# 20. 'two' - 0.32% confidence
#
# Line 6: "The spruces rough in the distant glitter"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'hills' - 6.36% confidence
# 2. 'past' - 5.83% confidence
# 3. 'mountains' - 2.97% confidence
# 4. ',' - 2.79% confidence
# 5. 'sky' - 2.44% confidence
# 6. 'future' - 1.98% confidence
# 7. 'horizon' - 1.97% confidence
# 8. 'night' - 1.49% confidence
# 9. 'woods' - 1.22% confidence
# 10. 'distance' - 1.00% confidence
# 11. 'shadows' - 1.00% confidence
# 12. 'morning' - 0.95% confidence
# 13. 'background' - 0.95% confidence
# 14. 'forest' - 0.89% confidence
# 15. 'corners' - 0.87% confidence
#    ^^^ This word will be used ^^^
# 16. 'air' - 0.78% confidence
# 17. 'and' - 0.69% confidence
# 18. 'desert' - 0.68% confidence
# 19. 'valley' - 0.67% confidence
# 20. 'sun' - 0.66% confidence
#
# Line 7: "Of the January sun; and not to think"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'be' - 16.31% confidence
# 2. 'mention' - 8.23% confidence
# 3. 'the' - 4.81% confidence
# 4. 'say' - 4.69% confidence
# 5. 'forget' - 2.43% confidence
# 6. 'speak' - 2.17% confidence
# 7. 'have' - 1.29% confidence
# 8. 'think' - 1.26% confidence
# 9. 'look' - 0.97% confidence
# 10. 'my' - 0.91% confidence
# 11. 'take' - 0.80% confidence
# 12. 'go' - 0.71% confidence
# 13. 'a' - 0.67% confidence
# 14. 'all' - 0.67% confidence
# 15. 'make' - 0.61% confidence
#    ^^^ This word will be used ^^^
# 16. 'do' - 0.52% confidence
# 17. 'get' - 0.52% confidence
# 18. 'any' - 0.51% confidence
# 19. 'see' - 0.49% confidence
# 20. 'give' - 0.49% confidence
#
# Line 8: "Of any misery in the sound of the wind,"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'trumpet' - 2.44% confidence
# 2. 'voice' - 2.19% confidence
# 3. 'bell' - 1.67% confidence
# 4. 'world' - 1.65% confidence
# 5. 'bells' - 1.07% confidence
# 6. 'wind' - 1.04% confidence
# 7. 'sound' - 1.00% confidence
# 8. 'music' - 0.89% confidence
# 9. 'drum' - 0.86% confidence
# 10. 'earth' - 0.84% confidence
# 11. 'sun' - 0.71% confidence
# 12. 'waves' - 0.67% confidence
# 13. 'drums' - 0.54% confidence
# 14. 'war' - 0.51% confidence
# 15. 'door' - 0.51% confidence
#    ^^^ This word will be used ^^^
# 16. 'sea' - 0.49% confidence
# 17. 'great' - 0.49% confidence
# 18. 'song' - 0.48% confidence
# 19. 'water' - 0.42% confidence
# 20. 'car' - 0.40% confidence
#
# Line 9: "In the sound of a few leaves,"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'words' - 3.48% confidence
# 2. 'voices' - 2.31% confidence
# 3. 'of' - 2.29% confidence
# 4. 'gunshots' - 2.09% confidence
# 5. 'feet' - 1.36% confidence
# 6. 'clicks' - 1.34% confidence
# 7. 'shots' - 1.25% confidence
# 8. 'more' - 1.17% confidence
# 9. 'minutes' - 1.05% confidence
# 10. 'loud' - 0.98% confidence
# 11. 'seconds' - 0.77% confidence
# 12. 'explosions' - 0.57% confidence
# 13. 'footsteps' - 0.56% confidence
# 14. 'people' - 0.52% confidence
# 15. 'taps' - 0.52% confidence
#    ^^^ This word will be used ^^^
# 16. 'bells' - 0.49% confidence
# 17. 'lines' - 0.48% confidence
# 18. 'fingers' - 0.45% confidence
# 19. 'r' - 0.44% confidence
# 20. ',' - 0.41% confidence
#
# Line 10: "Which is the sound of the land"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'wind' - 1.17% confidence
# 2. 'car' - 1.07% confidence
# 3. 'door' - 0.94% confidence
# 4. 'engine' - 0.85% confidence
# 5. 'water' - 0.82% confidence
# 6. 'sound' - 0.75% confidence
# 7. 'voice' - 0.73% confidence
# 8. 'bell' - 0.67% confidence
# 9. 'drum' - 0.55% confidence
# 10. 'music' - 0.55% confidence
# 11. 'gun' - 0.48% confidence
# 12. 'sun' - 0.48% confidence
# 13. 'ship' - 0.44% confidence
# 14. 'fire' - 0.37% confidence
# 15. 'man' - 0.36% confidence
#    ^^^ This word will be used ^^^
# 16. 'air' - 0.35% confidence
# 17. 'waves' - 0.31% confidence
# 18. 'bird' - 0.31% confidence
# 19. 'thunder' - 0.31% confidence
# 20. 'phone' - 0.30% confidence
#
# Line 11: "Full of the same wind"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. ',' - 5.23% confidence
# 2. '.' - 5.07% confidence
# 3. 'kind' - 1.79% confidence
# 4. 'name' - 1.55% confidence
# 5. 'thing' - 1.48% confidence
# 6. 'type' - 1.45% confidence
# 7. 'day' - 1.19% confidence
# 8. 'material' - 0.96% confidence
# 9. 'story' - 0.94% confidence
# 10. 'time' - 0.76% confidence
# 11. 'sort' - 0.73% confidence
# 12. 'year' - 0.64% confidence
# 13. 'color' - 0.59% confidence
# 14. ':' - 0.56% confidence
# 15. '' - 0.56% confidence
#    ^^^ This word will be used ^^^
# 16. 'size' - 0.48% confidence
# 17. 'and' - 0.46% confidence
# 18. 'way' - 0.44% confidence
# 19. 'character' - 0.43% confidence
# 20. 'weight' - 0.42% confidence
#
# Line 12: "That is blowing in the same bare place"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. '-' - 4.74% confidence
# 2. 'foot' - 3.32% confidence
# 3. 'feet' - 2.85% confidence
# 4. 'chest' - 2.81% confidence
# 5. 'hands' - 2.73% confidence
# 6. ',' - 2.19% confidence
# 7. 'air' - 2.17% confidence
# 8. 'shoulders' - 1.90% confidence
# 9. 'footed' - 1.81% confidence
# 10. 'bones' - 1.42% confidence
# 11. 'head' - 1.41% confidence
# 12. 'hand' - 1.30% confidence
# 13. 'space' - 1.27% confidence
# 14. 'back' - 1.09% confidence
# 15. 'face' - 1.05% confidence
#    ^^^ This word will be used ^^^
# 16. 'area' - 1.02% confidence
# 17. 'bottom' - 1.02% confidence
# 18. 'handed' - 0.96% confidence
# 19. 'water' - 0.90% confidence
# 20. 'skin' - 0.89% confidence
#
# Line 13: "For the listener, who listens in the snow,"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'background' - 16.32% confidence
# 2. 'same' - 7.84% confidence
# 3. 'middle' - 2.07% confidence
# 4. 'first' - 1.74% confidence
# 5. 'browser' - 1.58% confidence
# 6. '"' - 1.17% confidence
# 7. 'morning' - 0.87% confidence
# 8. 'following' - 0.74% confidence
# 9. 'main' - 0.73% confidence
# 10. 'studio' - 0.70% confidence
# 11. 'most' - 0.66% confidence
# 12. 'order' - 0.65% confidence
# 13. 'room' - 0.64% confidence
# 14. 'default' - 0.56% confidence
# 15. 'form' - 0.53% confidence
#    ^^^ This word will be used ^^^
# 16. 'direction' - 0.51% confidence
# 17. 'context' - 0.51% confidence
# 18. 'current' - 0.48% confidence
# 19. 'audio' - 0.46% confidence
# 20. 'usual' - 0.46% confidence
#
# Line 14: "And, nothing himself, beholds"
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'but' - 14.43% confidence
# 2. 'nothing' - 6.89% confidence
# 3. 'except' - 5.01% confidence
# 4. 'no' - 3.25% confidence
# 5. 'and' - 3.16% confidence
# 6. 'he' - 2.70% confidence
# 7. 'I' - 2.31% confidence
# 8. 'not' - 2.24% confidence
# 9. 'or' - 2.16% confidence
# 10. 'though' - 2.09% confidence
# 11. 'it' - 2.04% confidence
# 12. 'of' - 1.85% confidence
# 13. 'as' - 1.48% confidence
# 14. 'for' - 1.46% confidence
# 15. 'however' - 1.42% confidence
#    ^^^ This word will be used ^^^
# 16. 'so' - 1.35% confidence
# 17. 'that' - 1.28% confidence
# 18. 'the' - 1.12% confidence
# 19. 'just' - 1.05% confidence
# 20. 'only' - 0.95% confidence
#
# Line 15: "Nothing that is not there and the nothing that is."
# ----------------------------------------
# Top 20 possibilities for the last word:
# 1. 'is' - 64.99% confidence
# 2. 'has' - 2.63% confidence
# 3. 'does' - 1.97% confidence
# 4. 'was' - 1.71% confidence
# 5. 'I' - 1.44% confidence
# 6. 'we' - 1.43% confidence
# 7. 'isn' - 1.36% confidence
# 8. ''s' - 1.30% confidence
# 9. 'you' - 1.07% confidence
# 10. 'comes' - 1.05% confidence
# 11. 'exists' - 0.89% confidence
# 12. 'can' - 0.87% confidence
# 13. 'cannot' - 0.87% confidence
# 14. 'will' - 0.80% confidence
# 15. 'doesn' - 0.72% confidence
#    ^^^ This word will be used ^^^
# 16. 'it' - 0.62% confidence
# 17. 'goes' - 0.58% confidence
# 18. 'never' - 0.51% confidence
# 19. 'would' - 0.40% confidence
# 20. 'remains' - 0.36% confidence
#
#
# Final Modified Poem:
# --------------------------------------------------
# The Snow Man
# by Wallace Stevens (1879-1955)
# One must have a mind of it
# To regard the frost and the lack
# Of the pine-trees crusted with dust
# And have been cold a long period
# To behold the junipers shagged with silver
# The spruces rough in the distant corners
# Of the January sun; and not to make
# Of any misery in the sound of the door
# In the sound of a few taps
# Which is the sound of the man
# Full of the same
# That is blowing in the same bare face
# For the listener, who listens in the form
# And, nothing himself, however
# Nothing that is not there and the nothing that doesn
